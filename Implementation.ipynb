# %% [markdown]
# # Part 1 Meaning from Text
#
# ## 1) Imports and Downloads

# %%
import os
import requests
import nltk
import numpy as np
import scipy.sparse
import scipy.stats
import sklearn.decomposition
import sklearn.metrics.pairwise

import warnings
warnings.filterwarnings("ignore")

os.makedirs('data', exist_ok = True)
nltk.download(info_or_id = 'brown', download_dir = 'data')
nltk.data.path = ['data'] # makihng sure I use the one in data/

import nltk.corpus
# Out:
# [nltk_data] Downloading package brown to data...
# [nltk_data]   Package brown is already up-to-date!

# %% [markdown]
# ## 2) Extracting common words

# %%
brownWords = nltk.corpus.brown.words()
wordsDist = nltk.FreqDist((w.lower() for w in brownWords))
sortedWords = sorted(wordsDist.items(), reverse=True, key = lambda x : x[1])

# %% [markdown]
# This gets us all the words from there we can remove nonword tokens and reduce to the top 5000

# %%
Wc = [(w,c) for w,c in sortedWords if not re.match('.*[^a-z]+', w)][:5000]

# %% [markdown]
# Then the top and bottom words are:

# %%
print("Top 5 words:")
for w,c in Wc[:5]:
    print(w)
print()
print("Bottom 5 words:")
for w,c in Wc[:-6:-1]:
    print(w)
# Out:
# Top 5 words:
# the
# of
# and
# to
# a
#
# Bottom 5 words:
# letch
# haney
# killpath
# rourke
# vertex

# %% [markdown]
# Gettign the RG65 dataset

# %%
r = requests.get('https://raw.githubusercontent.com/AlexGrinch/ro_sgns/master/datasets/rg65.csv') # could not fing a better source
rgWords = list(set([w for l in r.text.split('\n') for w in l.strip().split(';')[:2]]))
print(f"{len(rgWords)} words found in RG65")
# Out:
# 48 words found in RG65

# %%
for rgW in rgWords:
    if rgW not in [w[0] for w in Wc]: # polynomial O is best O
        Wc.append((rgW, wordsDist[rgW]))
W = set((w for w,c in Wc))
print(f"Now we have {len(W)} words in W")
# Out:
# Now we have 5030 words in W

# %% [markdown]
# ## 3) Construct Bigram Matrix

# %%
M1dict = {}
M1index = {w : i for i, w in enumerate(W)}
for w1, w2 in zip(brownWords[:-1], brownWords[1:]):
    try:
        w1i = M1index[w1.lower()]
        w2i = M1index[w2.lower()]
    except KeyError:
        pass
    else:
        try:
            M1dict[(w1i, w2i)] += 1
        except KeyError:
            M1dict[(w1i, w2i)] = 1
dat = []
i = []
j = []
for (k1, k2), v in M1dict.items():
    dat.append(v)
    i.append(k1)
    j.append(k2)

# %%
M1 = scipy.sparse.coo_matrix((dat, (i,j)), shape = (len(W), len(W)))
M1 = M1 + M1.T

# %%
print(f"Testing for the count on 'the' and 'driver': {M1[M1index['the'], M1index['driver']]}")
# Out:
# Testing for the count on 'the' and 'driver': 23

# %% [markdown]
# ## 4) Calculate PPMI

# %%
m = np.matrix(M1.toarray())
m = m / m.sum() # Convert to probs

#some annoying zeros show up
cond = (M1 > 0).toarray()
x = m.sum(axis = 0)@m.sum(axis = 0).T
y = np.ones((len(W), len(W)))


M1P = np.where(cond, np.log2(M1 / np.where(cond, x, y)), np.zeros((len(W), len(W))))
M1P[M1P < 0] = 0

# %% [markdown]
# ## 5) Do the LSA

# %%
M2_10 = sklearn.decomposition.PCA(n_components = 10).fit_transform(M1P)
M2_100 = sklearn.decomposition.PCA(n_components = 100).fit_transform(M1P)
M2_300 = sklearn.decomposition.PCA(n_components = 300).fit_transform(M1P)

# %% [markdown]
# # 6) Extract the Word Pairs, with Human Rankings

# %%
rgSets = [s.strip().split(';') for s in r.text.split('\n')]
P = [(w1,w2) for w1, w2, s in rgSets]
S = [float(s) for w1, w2, s in rgSets]

# %% [markdown]
# # 7) Extract the Word Pairs, for Matrices Vectors

# %%
S_M1 = []
S_M1P = []
S_M2_10 = []
S_M2_100 = []
S_M2_300 = []

for w1,w2 in P:
    w1i = M1index[w1]
    w2i = M1index[w2]
    for m, s in zip([M1, M1P, M2_10, M2_100, M2_300], [S_M1, S_M1P, S_M2_10, S_M2_100, S_M2_300]):
        try:
            m = m.toarray()
        except:
            pass
        s.append(sklearn.metrics.pairwise.cosine_similarity(m[w1i].reshape(1,-1), m[w2i].reshape(1,-1))[0][0])

# %% [markdown]
# # 8) Report results

# %%
print(f"The Pearson coefficient between between humans and M1 is: {scipy.stats.pearsonr(S_M1, S)[0]:.4f}")
print(f"The Pearson coefficient between between humans and M1+ is: {scipy.stats.pearsonr(S_M1P, S)[0]:.4f}")
print(f"The Pearson coefficient between between humans and M2_10 is: {scipy.stats.pearsonr(S_M2_10, S)[0]:.4f}")
print(f"The Pearson coefficient between between humans and M2_100 is: {scipy.stats.pearsonr(S_M2_100, S)[0]:.4f}")
print(f"The Pearson coefficient between between humans and M2_300 is: {scipy.stats.pearsonr(S_M2_300, S)[0]:.4f}")
# Out:
# The Pearson coefficient between between humans and M1 is: 0.1047
# The Pearson coefficient between between humans and M1+ is: 0.1957
# The Pearson coefficient between between humans and M2_10 is: 0.0709
# The Pearson coefficient between between humans and M2_100 is: 0.1497
# The Pearson coefficient between between humans and M2_300 is: 0.1592

# %% [markdown]
# # Part 2 Meaning Construction from Text
# ## 1) Import

# %%
import gensim

#the word2vec pretrain is hard to download without a browser so I did that manually

# %% [markdown]
# # 2) Load the word2vec model

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('data/GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
S_w2v = []
for w1, w2 in P:
    S_w2v.append(sklearn.metrics.pairwise.cosine_similarity(model[w1].reshape(1,-1), model[w2].reshape(1,-1))[0][0])

# %%
print(f"The pearson correlation coeffienct betweeen humans and the word2vec model is:\n{scipy.stats.pearsonr(S_w2v, S)[0]:.4f}")
# Out:
# The pearson correlation coeffienct betweeen humans and the word2vec model is:
# 0.7721

# %% [markdown]
# # 3) Do Analogies test

# %%
r_analogies = requests.get('http://www.fit.vutbr.cz/~imikolov/rnnlm/word-test.v1.txt')

# %%
analogies = {}     
for l in r_analogies.text.split('\n')[1:]:
    if l.startswith(':'):
        currentName = l[1:].strip()
        analogies[currentName] = []
    else:
        analogies[currentName].append(l.lower().strip().split())

# %%
#For the analogies we'll limit it to family for sematic and gram7-past-tense for syntatic

M1index_reverse = {v : k for k,v in M1index.items()}

words_sem = analogies['family']

good_analogies = []
for analogy in words_sem:
    if len([w for w in analogy if w in M1index]) == 4:
        good_analogies.append(analogy)
#Reducing set some more for better run time
good_analogies_sem = sorted(good_analogies)

#This seems to have at least a few hits
words_sem = analogies['gram7-past-tense']

good_analogies = []
for analogy in words_sem:
    if len([w for w in analogy if w in M1index]) == 4:
        good_analogies.append(analogy)
#Reducing set some more for better run time
good_analogies_syn = sorted(good_analogies)

print(f"We have {len(good_analogies_sem)} sematic and {len(good_analogies_syn)} syntatic analogies to test")
# Out:
# We have 90 sematic and 600 syntatic analogies to test

# %%
word2vec_results_syn = []
M300_results_syn = []


for w1, w2, w3, w4 in good_analogies_syn:
    w2vRet = model.most_similar(positive=[w3, w1], negative=[w2], topn = 1)
    if w2vRet[0][0].lower() == w4:
        word2vec_results_syn.append(True)
    else:
        word2vec_results_syn.append(False)
    v = M2_300[M1index[w1]] + M2_300[M1index[w2]] - M2_300[M1index[w3]]
    idM300 = np.linalg.norm((M2_300 - v), axis = 1).argmin()
    if M1index_reverse[idM300] == w4:
        M300_results_syn.append(True)
    else:
        M300_results_syn.append(False)
    print(w1, w2, w3, w4, ':' ,w2vRet[0][0], M1index_reverse[idM300])
# Out:
# falling fell feeding fed : feed fell
# falling fell flying flew : fly fell
# falling fell going went : coming fell
# falling fell increasing increased : decreasing fell
# falling fell knowing knew : Knowing fell
# falling fell listening listened : Listening fell
# falling fell looking looked : seeing fell
# falling fell moving moved : Moving fell
# falling fell paying paid : pay fell
# falling fell playing played : play fell
# falling fell reading read : read fell
# falling fell running ran : Running fell
# falling fell saying said : telling fell
# falling fell seeing saw : noticing fell
# falling fell selling sold : buying fell
# falling fell singing sang : sing fell
# falling fell sitting sat : sit fell
# falling fell sleeping slept : sleep fell
# falling fell spending spent : Spending fell
# falling fell striking struck : fanning fell
# falling fell taking took : take fell
# falling fell thinking thought : talking fell
# falling fell walking walked : Walking fell
# falling fell writing wrote : penning fell
# feeding fed falling fell : dropping fed
# feeding fed flying flew : fly fed
# feeding fed going went : doing lo
# feeding fed increasing increased : decreasing fed
# feeding fed knowing knew : Knowing fed
# feeding fed listening listened : Listening fed
# feeding fed looking looked : searching feeding
# feeding fed moving moved : relocating mason
# feeding fed paying paid : pay fed
# feeding fed playing played : play fed
# feeding fed reading read : writing fed
# feeding fed running ran : Running founded
# feeding fed saying said : telling fed
# feeding fed seeing saw : noticing fed
# feeding fed selling sold : buying fed
# feeding fed singing sang : sing fed
# feeding fed sitting sat : Sitting feeding
# feeding fed sleeping slept : sleep fed
# feeding fed spending spent : Spending fed
# feeding fed striking struck : struck fed
# feeding fed taking took : take rico
# feeding fed thinking thought : Thinking fed
# feeding fed walking walked : jogging fed
# feeding fed writing wrote : penning fed
# flying flew falling fell : dropping flew
# flying flew feeding fed : feed flew
# flying flew going went : gonna oracle
# flying flew increasing increased : decreasing flew
# flying flew knowing knew : Knowing flew
# flying flew listening listened : Listening flew
# flying flew looking looked : seeing flew
# flying flew moving moved : Moving flew
# flying flew paying paid : pay flew
# flying flew playing played : play flew
# flying flew reading read : writing flew
# flying flew running ran : Running flew
# flying flew saying said : telling flew
# flying flew seeing saw : noticing flew
# flying flew selling sold : buying flew
# flying flew singing sang : sing flew
# flying flew sitting sat : sit flew
# flying flew sleeping slept : sleep flew
# flying flew spending spent : Spending flew
# flying flew striking struck : fanning flew
# flying flew taking took : take flew
# flying flew thinking thought : imagining flew
# flying flew walking walked : walk flew
# flying flew writing wrote : reading flew
# going went falling fell : dropping went
# going went feeding fed : feed went
# going went flying flew : gonna went
# going went increasing increased : decreasing went
# going went knowing knew : Knowing went
# going went listening listened : listen went
# going went looking looked : hoping went
# going went moving moved : Moving went
# going went paying paid : pay went
# going went playing played : play went
# going went reading read : read went
# going went running ran : gonna went
# going went saying said : telling went
# going went seeing saw : see went
# going went selling sold : buying went
# going went singing sang : sing went
# going went sitting sat : sit went
# going went sleeping slept : sleep went
# going went spending spent : Spending went
# going went striking struck : shaking_Vidale went
# going went taking took : take went
# going went thinking thought : think went
# going went walking walked : walk went
# going went writing wrote : writting went
# increasing increased falling fell : dropping increased
# increasing increased feeding fed : feed increased
# increasing increased flying flew : fly increased
# increasing increased going went : gonna increased
# increasing increased knowing knew : realizing increased
# increasing increased listening listened : Listening increased
# increasing increased looking looked : look increased
# increasing increased moving moved : Moving increased
# increasing increased paying paid : pay increased
# increasing increased playing played : play increased
# increasing increased reading read : read increased
# increasing increased running ran : Running increased
# increasing increased saying said : telling increased
# increasing increased seeing saw : witnessing increased
# increasing increased selling sold : buying increased
# increasing increased singing sang : sing increased
# increasing increased sitting sat : Sitting increased
# increasing increased sleeping slept : falling_asleep increased
# increasing increased spending spent : discretionary_spending increased
# increasing increased striking struck : fanning increased
# increasing increased taking took : take increased
# increasing increased thinking thought : imagining increased
# increasing increased walking walked : walk increased
# increasing increased writing wrote : composing increased
# knowing knew falling fell : slipping knew
# knowing knew feeding fed : feed knew
# knowing knew flying flew : fly knew
# knowing knew going went : you knew
# knowing knew increasing increased : decreasing knew
# knowing knew listening listened : Listening knew
# knowing knew looking looked : look knew
# knowing knew moving moved : Moving knew
# knowing knew paying paid : Paying knew
# knowing knew playing played : Playing knew
# knowing knew reading read : read knew
# knowing knew running ran : Running knew
# knowing knew saying said : insisting knew
# knowing knew seeing saw : having knew
# knowing knew selling sold : buying knew
# knowing knew singing sang : sing knew
# knowing knew sitting sat : Sitting knew
# knowing knew sleeping slept : sleep knew
# knowing knew spending spent : Spending knew
# knowing knew striking struck : fanning knew
# knowing knew taking took : Taking knew
# knowing knew thinking thought : imagining knew
# knowing knew walking walked : walk knew
# knowing knew writing wrote : reading knew
# listening listened falling fell : dropping listened
# listening listened feeding fed : Feeding listened
# listening listened flying flew : Flying listened
# listening listened going went : gonna listened
# listening listened increasing increased : decreasing listened
# listening listened knowing knew : Knowing listened
# listening listened looking looked : searching listened
# listening listened moving moved : Moving listened
# listening listened paying paid : Paying listened
# listening listened playing played : play listened
# listening listened reading read : writing listened
# listening listened running ran : Running listened
# listening listened saying said : telling listened
# listening listened seeing saw : noticing listened
# listening listened selling sold : buying listened
# listening listened singing sang : crooning listened
# listening listened sitting sat : lounging listened
# listening listened sleeping slept : sleep listened
# listening listened spending spent : Spending listened
# listening listened striking struck : struck listened
# listening listened taking took : Taking listened
# listening listened thinking thought : daydreaming listened
# listening listened walking walked : jogging listened
# listening listened writing wrote : reading listened
# looking looked falling fell : dropping looked
# looking looked feeding fed : feed looked
# looking looked flying flew : Flying looked
# looking looked going went : trying looked
# looking looked increasing increased : decreasing looked
# looking looked knowing knew : wanting looked
# looking looked listening listened : Listening looked
# looking looked moving moved : pushing looked
# looking looked paying paid : pay looked
# looking looked playing played : Playing looked
# looking looked reading read : writing looked
# looking looked running ran : Running looked
# looking looked saying said : asking looked
# looking looked seeing saw : anticipating looked
# looking looked selling sold : buying looked
# looking looked singing sang : sing looked
# looking looked sitting sat : sit looked
# looking looked sleeping slept : searching looked
# looking looked spending spent : Spending looked
# looking looked striking struck : fanning looked
# looking looked taking took : seeking looked
# looking looked thinking thought : talking looked
# looking looked walking walked : Walking looked
# looking looked writing wrote : penning looked
# moving moved falling fell : dropping moved
# moving moved feeding fed : Feeding moved
# moving moved flying flew : zipping moved
# moving moved going went : gonna moved
# moving moved increasing increased : decreasing moved
# moving moved knowing knew : Knowing moved
# moving moved listening listened : Listening moved
# moving moved looking looked : seeing moved
# moving moved paying paid : pay moved
# moving moved playing played : play moved
# moving moved reading read : read moved
# moving moved running ran : Running moved
# moving moved saying said : telling moved
# moving moved seeing saw : witnessing moved
# moving moved selling sold : buying moved
# moving moved singing sang : sing moved
# moving moved sitting sat : Sitting moved
# moving moved sleeping slept : falling_asleep moved
# moving moved spending spent : Spending moved
# moving moved striking struck : guardrail_Hersman moved
# moving moved taking took : Taking moved
# moving moved thinking thought : talking moved
# moving moved walking walked : Walking moved
# moving moved writing wrote : reading moved
# paying paid falling fell : dropping paid
# paying paid feeding fed : feed paid
# paying paid flying flew : fly paid
# paying paid going went : gonna paid
# paying paid increasing increased : decreasing paid
# paying paid knowing knew : having paid
# paying paid listening listened : listen paid
# paying paid looking looked : searching paid
# paying paid moving moved : shifting paid
# paying paid playing played : play paid
# paying paid reading read : read paid
# paying paid running ran : Running paid
# paying paid saying said : telling paid
# paying paid seeing saw : noticing paid
# paying paid selling sold : buying paid
# paying paid singing sang : sing paid
# paying paid sitting sat : Sitting paid
# paying paid sleeping slept : falling_asleep paid
# paying paid spending spent : discretionary_spending paid
# paying paid striking struck : fanning paid
# paying paid taking took : take paid
# paying paid thinking thought : imagining paid
# paying paid walking walked : walk paid
# paying paid writing wrote : reading paid
# playing played falling fell : dropping played
# playing played feeding fed : feed played
# playing played flying flew : fly played
# playing played going went : gonna played
# playing played increasing increased : decreasing played
# playing played knowing knew : Knowing playing
# playing played listening listened : Listening played
# playing played looking looked : searching played
# playing played moving moved : Moving played
# playing played paying paid : pay played
# playing played reading read : writing played
# playing played running ran : Running played
# playing played saying said : telling played
# playing played seeing saw : noticing played
# playing played selling sold : buying played
# playing played singing sang : sing played
# playing played sitting sat : Sitting played
# playing played sleeping slept : sleep played
# playing played spending spent : Spending played
# playing played striking struck : fanning played
# playing played taking took : take played
# playing played thinking thought : dreaming played
# playing played walking walked : jogging played
# playing played writing wrote : composing played
# reading read falling fell : fell read
# reading read feeding fed : Feeding read
# reading read flying flew : Flying read
# reading read going went : coming read
# reading read increasing increased : decreasing read
# reading read knowing knew : having read
# reading read listening listened : Listening read
# reading read looking looked : searching read
# reading read moving moved : inching read
# reading read paying paid : pay read
# reading read playing played : Playing read
# reading read running ran : Running read
# reading read saying said : suggesting read
# reading read seeing saw : witnessing read
# reading read selling sold : buying read
# reading read singing sang : sing read
# reading read sitting sat : Sitting read
# reading read sleeping slept : sleep read
# reading read spending spent : Spending read
# reading read striking struck : fanning read
# reading read taking took : Taking read
# reading read thinking thought : imagining reading
# reading read walking walked : Walking read
# reading read writing wrote : composing read
# running ran falling fell : dropping ran
# running ran feeding fed : feed ran
# running ran flying flew : fly ran
# running ran going went : gonna ran
# running ran increasing increased : decreasing ran
# running ran knowing knew : Knowing ran
# running ran listening listened : listen ran
# running ran looking looked : hoping ran
# running ran moving moved : Moving ran
# running ran paying paid : pay ran
# running ran playing played : play ran
# running ran reading read : writing ran
# running ran saying said : insisting ran
# running ran seeing saw : experiencing ran
# running ran selling sold : buying ran
# running ran singing sang : sing ran
# running ran sitting sat : sit ran
# running ran sleeping slept : sleep ran
# running ran spending spent : Spending ran
# running ran striking struck : fanning ran
# running ran taking took : take ran
# running ran thinking thought : talking ran
# running ran walking walked : walk ran
# running ran writing wrote : penning ran
# saying said falling fell : dropping said
# saying said feeding fed : feed said
# saying said flying flew : giant_swatter said
# saying said going went : gonna said
# saying said increasing increased : decreasing said
# saying said knowing knew : believing said
# saying said listening listened : listen said
# saying said looking looked : look said
# saying said moving moved : move said
# saying said paying paid : pay said
# saying said playing played : play said
# saying said reading read : read said
# saying said running ran : Running said
# saying said seeing saw : having said
# saying said selling sold : buying said
# saying said singing sang : sing said
# saying said sitting sat : sit said
# saying said sleeping slept : slept said
# saying said spending spent : Spending said
# saying said striking struck : Striking said
# saying said taking took : Taking said
# saying said thinking thought : believing said
# saying said walking walked : walk said
# saying said writing wrote : write said
# seeing saw falling fell : dropping saw
# seeing saw feeding fed : Feeding saw
# seeing saw flying flew : fly saw
# seeing saw going went : coming saw
# seeing saw increasing increased : decreasing saw
# seeing saw knowing knew : Knowing saw
# seeing saw listening listened : Listening saw
# seeing saw looking looked : searching saw
# seeing saw moving moved : Moving saw
# seeing saw paying paid : Paying saw
# seeing saw playing played : play saw
# seeing saw reading read : writing saw
# seeing saw running ran : Running saw
# seeing saw saying said : telling saw
# seeing saw selling sold : buying saw
# seeing saw singing sang : sing saw
# seeing saw sitting sat : sit saw
# seeing saw sleeping slept : Sleeping saw
# seeing saw spending spent : Spending saw
# seeing saw striking struck : fanning saw
# seeing saw taking took : getting saw
# seeing saw thinking thought : imagining saw
# seeing saw walking walked : walk saw
# seeing saw writing wrote : reading saw
# selling sold falling fell : dropping sold
# selling sold feeding fed : Feeding sold
# selling sold flying flew : fly sold
# selling sold going went : gonna selling
# selling sold increasing increased : decreasing sold
# selling sold knowing knew : Knowing sold
# selling sold listening listened : Listening sold
# selling sold looking looked : look selling
# selling sold moving moved : Moving selling
# selling sold paying paid : pay sold
# selling sold playing played : play selling
# selling sold reading read : writing sold
# selling sold running ran : Running sold
# selling sold saying said : telling selling
# selling sold seeing saw : noticing sold
# selling sold singing sang : sing sold
# selling sold sitting sat : Sitting selling
# selling sold sleeping slept : sleep sold
# selling sold spending spent : Spending sold
# selling sold striking struck : fanning sold
# selling sold taking took : Taking selling
# selling sold thinking thought : Thinking sold
# selling sold walking walked : Walking sold
# selling sold writing wrote : penning sold
# singing sang falling fell : dropping sang
# singing sang feeding fed : feed sang
# singing sang flying flew : fly sang
# singing sang going went : gonna sang
# singing sang increasing increased : decreasing sang
# singing sang knowing knew : Knowing sang
# singing sang listening listened : Listening singing
# singing sang looking looked : searching sang
# singing sang moving moved : move sang
# singing sang paying paid : pay sang
# singing sang playing played : play sang
# singing sang reading read : writing sang
# singing sang running ran : Running sang
# singing sang saying said : telling sang
# singing sang seeing saw : noticing sang
# singing sang selling sold : buying sang
# singing sang sitting sat : sit sang
# singing sang sleeping slept : sleep sang
# singing sang spending spent : Spending sang
# singing sang striking struck : fanning sang
# singing sang taking took : take sang
# singing sang thinking thought : daydreaming sang
# singing sang walking walked : walk sang
# singing sang writing wrote : composing sang
# sitting sat falling fell : dropping sat
# sitting sat feeding fed : feed sat
# sitting sat flying flew : fly sat
# sitting sat going went : gonna sat
# sitting sat increasing increased : decreasing sat
# sitting sat knowing knew : Knowing sat
# sitting sat listening listened : Listening sat
# sitting sat looking looked : seeing sat
# sitting sat moving moved : move sat
# sitting sat paying paid : pay sat
# sitting sat playing played : play sat
# sitting sat reading read : writing sat
# sitting sat running ran : Running sat
# sitting sat saying said : implying sat
# sitting sat seeing saw : noticing sat
# sitting sat selling sold : buying sat
# sitting sat singing sang : sing sat
# sitting sat sleeping slept : sleep sat
# sitting sat spending spent : Spending sat
# sitting sat striking struck : fanning sat
# sitting sat taking took : take sat
# sitting sat thinking thought : dreaming sat
# sitting sat walking walked : walk sat
# sitting sat writing wrote : reading sat
# sleeping slept falling fell : dropping sleeping
# sleeping slept feeding fed : Feeding slept
# sleeping slept flying flew : Flying slept
# sleeping slept going went : gonna furnace
# sleeping slept increasing increased : decreasing slept
# sleeping slept knowing knew : Knowing slept
# sleeping slept listening listened : Listening slept
# sleeping slept looking looked : searching saddle
# sleeping slept moving moved : shifting slept
# sleeping slept paying paid : pay slept
# sleeping slept playing played : play slept
# sleeping slept reading read : writing slept
# sleeping slept running ran : Running slept
# sleeping slept saying said : stating slept
# sleeping slept seeing saw : noticing slept
# sleeping slept selling sold : buying slept
# sleeping slept singing sang : sing slept
# sleeping slept sitting sat : Sitting slept
# sleeping slept spending spent : Spending slept
# sleeping slept striking struck : Striking slept
# sleeping slept taking took : Taking slept
# sleeping slept thinking thought : Thinking slept
# sleeping slept walking walked : Walking slept
# sleeping slept writing wrote : composing slept
# spending spent falling fell : tumbling spent
# spending spent feeding fed : feed spent
# spending spent flying flew : fly spent
# spending spent going went : gonna spent
# spending spent increasing increased : decreasing spent
# spending spent knowing knew : Knowing spent
# spending spent listening listened : listen spent
# spending spent looking looked : look spent
# spending spent moving moved : move spent
# spending spent paying paid : pay spent
# spending spent playing played : play spent
# spending spent reading read : Core_PCE spent
# spending spent running ran : Running spent
# spending spent saying said : telling spent
# spending spent seeing saw : see spent
# spending spent selling sold : buying spent
# spending spent singing sang : sing spent
# spending spent sitting sat : sit spent
# spending spent sleeping slept : sleep spent
# spending spent striking struck : Striking spent
# spending spent taking took : take spent
# spending spent thinking thought : newfound_frugality spent
# spending spent walking walked : walk spent
# spending spent writing wrote : reading spent
# striking struck falling fell : dropping struck
# striking struck feeding fed : feed struck
# striking struck flying flew : Flying struck
# striking struck going went : gonna struck
# striking struck increasing increased : decreasing struck
# striking struck knowing knew : having struck
# striking struck listening listened : listen struck
# striking struck looking looked : look struck
# striking struck moving moved : Moving struck
# striking struck paying paid : pay struck
# striking struck playing played : play struck
# striking struck reading read : read struck
# striking struck running ran : Running struck
# striking struck saying said : telling struck
# striking struck seeing saw : noticing striking
# striking struck selling sold : buying struck
# striking struck singing sang : sing struck
# striking struck sitting sat : sit struck
# striking struck sleeping slept : sleep struck
# striking struck spending spent : Spending struck
# striking struck taking took : take striking
# striking struck thinking thought : imagining struck
# striking struck walking walked : walk struck
# striking struck writing wrote : composing struck
# taking took falling fell : dropping took
# taking took feeding fed : feed took
# taking took flying flew : fly took
# taking took going went : doing took
# taking took increasing increased : decreasing took
# taking took knowing knew : realizing took
# taking took listening listened : Listening took
# taking took looking looked : seeing took
# taking took moving moved : shifting took
# taking took paying paid : pay took
# taking took playing played : play took
# taking took reading read : writing took
# taking took running ran : Running took
# taking took saying said : suggesting took
# taking took seeing saw : witnessing took
# taking took selling sold : buying took
# taking took singing sang : sing took
# taking took sitting sat : sit took
# taking took sleeping slept : sleep took
# taking took spending spent : Spending took
# taking took striking struck : fanning took
# taking took thinking thought : talking took
# taking took walking walked : Walking took
# taking took writing wrote : penning took
# thinking thought falling fell : slipping thought
# thinking thought feeding fed : feed thought
# thinking thought flying flew : flies thought
# thinking thought going went : coming thought
# thinking thought increasing increased : decreasing thought
# thinking thought knowing knew : imagining thought
# thinking thought listening listened : Listening thought
# thinking thought looking looked : look thought
# thinking thought moving moved : shifting thought
# thinking thought paying paid : pays thought
# thinking thought playing played : play thought
# thinking thought reading read : writing thought
# thinking thought running ran : Running thought
# thinking thought saying said : telling thought
# thinking thought seeing saw : noticing thought
# thinking thought selling sold : buying thought
# thinking thought singing sang : sing thought
# thinking thought sitting sat : Sitting thought
# thinking thought sleeping slept : sleep thought
# thinking thought spending spent : Spending thought
# thinking thought striking struck : fanning thought
# thinking thought taking took : Taking thought
# thinking thought walking walked : walk thought
# thinking thought writing wrote : penning thought
# walking walked falling fell : dropping walked
# walking walked feeding fed : feedings walked
# walking walked flying flew : traveling walked
# walking walked going went : gonna walked
# walking walked increasing increased : decreasing walked
# walking walked knowing knew : Knowing walked
# walking walked listening listened : Listening walked
# walking walked looking looked : searching walked
# walking walked moving moved : Moving walked
# walking walked paying paid : pay walked
# walking walked playing played : Playing walked
# walking walked reading read : solving_crossword_puzzles walked
# walking walked running ran : Running walked
# walking walked saying said : telling walked
# walking walked seeing saw : noticing walked
# walking walked selling sold : buying walked
# walking walked singing sang : sing walked
# walking walked sitting sat : lounging walked
# walking walked sleeping slept : sleep walked
# walking walked spending spent : Spending walked
# walking walked striking struck : fanning walked
# walking walked taking took : Taking walked
# walking walked thinking thought : imagining walked
# walking walked writing wrote : reading walked
# writing wrote falling fell : dropping wrote
# writing wrote feeding fed : Feeding wrote
# writing wrote flying flew : fly wrote
# writing wrote going went : doing wrote
# writing wrote increasing increased : decreasing wrote
# writing wrote knowing knew : having wrote
# writing wrote listening listened : listen wrote
# writing wrote looking looked : searching wrote
# writing wrote moving moved : Moving wrote
# writing wrote paying paid : pay wrote
# writing wrote playing played : play wrote
# writing wrote reading read : solving_crossword_puzzles wrote
# writing wrote running ran : Running wrote
# writing wrote saying said : telling wrote
# writing wrote seeing saw : noticing writing
# writing wrote selling sold : buying wrote
# writing wrote singing sang : sing wrote
# writing wrote sitting sat : sit wrote
# writing wrote sleeping slept : falling_asleep wrote
# writing wrote spending spent : Spending wrote
# writing wrote striking struck : stiking wrote
# writing wrote taking took : take wrote
# writing wrote thinking thought : dreaming wrote
# writing wrote walking walked : walk wrote

# %%
print(f"M_300 was correct {np.sum(M300_results_syn)} out of {len(M300_results_syn)} times on the syntactic task")
print(f"word2vec was correct {np.sum(word2vec_results_syn)} out of {len(word2vec_results_syn)} times on the syntactic task")
# Out:
# M_300 was correct 0 out of 600 times on the syntactic task
# word2vec was correct 12 out of 600 times on the syntactic task

# %%
word2vec_results_sem = []
M300_results_sem = []


for w1, w2, w3, w4 in good_analogies_sem:
    w2vRet = model.most_similar(positive=[w3, w1], negative=[w2], topn = 1)
    if w2vRet[0][0].lower() == w4:
        word2vec_results_sem.append(True)
    else:
        word2vec_results_sem.append(False)
    v = M2_300[M1index[w1]] + M2_300[M1index[w2]] - M2_300[M1index[w3]]
    idM300 = np.linalg.norm((M2_300 - v), axis = 1).argmin()
    if M1index_reverse[idM300] == w4:
        M300_results_sem.append(True)
    else:
        M300_results_sem.append(False)
    print(w1, w2, w3, w4, ':' ,w2vRet[0][0], M1index_reverse[idM300])
# Out:
# boy girl brother sister : younger_brother girl
# boy girl father mother : son girl
# boy girl he she : him joke
# boy girl his her : he lawyer
# boy girl husband wife : father girl
# boy girl king queen : kings girl
# boy girl man woman : teenager boy
# boy girl son daughter : father girl
# boy girl uncle aunt : nephew girl
# brother sister boy girl : man autograph
# brother sister father mother : son autograph
# brother sister he she : him autograph
# brother sister his her : himself autograph
# brother sister husband wife : father sister
# brother sister king queen : kings brother
# brother sister man woman : boy autograph
# brother sister son daughter : younger_brother brother
# brother sister uncle aunt : nephew sister
# father mother boy girl : son father
# father mother brother sister : younger_brother mother
# father mother he she : him soul
# father mother his her : himself neighbors
# father mother husband wife : son mother
# father mother king queen : kings mother
# father mother man woman : boy soul
# father mother son daughter : brother mother
# father mother uncle aunt : brother mother
# he she boy girl : man he
# he she brother sister : younger_brother he
# he she father mother : uncle he
# he she his her : himself he
# he she husband wife : father he
# he she king queen : kings he
# he she man woman : guy he
# he she son daughter : nephew he
# he she uncle aunt : nephew he
# his her boy girl : man his
# his her brother sister : younger_brother his
# his her father mother : younger_brother his
# his her he she : himself his
# his her husband wife : father his
# his her king queen : kings his
# his her man woman : guy his
# his her son daughter : younger_brother his
# his her uncle aunt : nephew his
# husband wife boy girl : girl husband
# husband wife brother sister : younger_brother wife
# husband wife father mother : son wife
# husband wife he she : she tongue
# husband wife his her : her victim
# husband wife king queen : kings wife
# husband wife man woman : woman husband
# husband wife son daughter : father husband
# husband wife uncle aunt : father wife
# king queen boy girl : man queen
# king queen brother sister : younger_brother king
# king queen father mother : uncle queen
# king queen he she : him realm
# king queen his her : he pillow
# king queen husband wife : father queen
# king queen man woman : boy lo
# king queen son daughter : father queen
# king queen uncle aunt : nephew king
# man woman boy girl : teenager man
# man woman brother sister : younger_brother man
# man woman father mother : uncle man
# man woman he she : him woman
# man woman his her : himself woman
# man woman husband wife : father man
# man woman king queen : kings man
# man woman son daughter : younger_brother man
# man woman uncle aunt : nephew man
# son daughter boy girl : teenager daughter
# son daughter brother sister : younger_brother son
# son daughter father mother : uncle daughter
# son daughter he she : him behalf
# son daughter his her : he saddle
# son daughter husband wife : father daughter
# son daughter king queen : kings son
# son daughter man woman : boy behalf
# son daughter uncle aunt : nephew son
# uncle aunt boy girl : son aunt
# uncle aunt brother sister : younger_brother aunt
# uncle aunt father mother : son aunt
# uncle aunt he she : him autograph
# uncle aunt his her : him autograph
# uncle aunt husband wife : father aunt
# uncle aunt king queen : kings uncle
# uncle aunt man woman : boy aunt
# uncle aunt son daughter : father uncle

# %%
print(f"M_300 was correct {np.sum(M300_results_sem)} out of {len(M300_results_sem)} times on the semantics task")
print(f"word2vec was correct {np.sum(word2vec_results_sem)} out of {len(M300_results_sem)} times on the semantics task")
# Out:
# M_300 was correct 0 out of 90 times on the semantics task
# word2vec was correct 4 out of 90 times on the semantics task
